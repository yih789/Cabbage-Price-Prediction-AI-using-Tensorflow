# %% [markdown]
# **선형회귀**
# * H = WX + b
# 데이터를 학습시켜서 '그나마' 가장 합리적인 직선을 찾는 것
#
# **즉, 주어진 데이터를 이용해 일차방정식을 수정해 나가는 것이다.**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **비용** : 가설이 얼마나 정확한 지 판단하는 기준
#
# => (예측 값 - 실제 값)제곱의 평균
#
# **비용이 적을수록 좋다.**

# %% [markdown]
# **경사하강** : 합리적인 식 도출
#
# 텐서플로우에서 경사 하강 라이브러리를 제공한다.
#
# ![image.png](data:image/png;base64,...)
#
#
#
#       *얼마나 점프해야 할까?
#
#
# *   곡선은 초반에 큰 폭으로 변화
# *   너무 작게 하면 오랫동안 학습
# *   너무 크게 하면 부정확

# %% [markdown]
# * **데이터를 수집할 때 데이터 간의 상관관계를 한 눈에 파악하기 위해 엑셀을 이용해 차트로 시각화 하는 습관을 갖자!**
